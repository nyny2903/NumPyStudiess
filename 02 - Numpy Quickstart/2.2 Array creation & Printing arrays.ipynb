# %% [markdown]
# <h2 style="text-align: center; font-family: 'Geneva'; color: #f17ea1; font-size:35px">
#   <span style="background-color: #facef9; padding: 2px 10px; border-radius: 6px; display: inline-block;">
#      Array creation
#   </span>
# </h2>
#
# lalalal
