# %% [markdown]
# <h2 style="text-align: center; font-family: 'Geneva'; color: #f17ea1;">
#   <span style="background-color: #facef9; padding: 2px 10px; border-radius: 6px; display: inline-block;">
#     <u> What is Numpy? </u>
#   </span>
# </h2>
#
# `NumPy` = Numerical Python
#
# `Why Numpy?` Because NumPy array is the most efficient way to represent and manipulate a grid of numbers (digital image = grid of numbers) in Python. Instead of worrying about slow loops, you can think in terms of matrices and vectors, which is gihow image processing algorithms are conceptually designed. We cant do efficient image processing in Python wht Numpy. It provides the core data structure (the ndarray) and tools for working with numerical data that are used by nearly every other scientific library, including:
# - Pandas
# - SciPy
# - Scikit-learn
# - Matplotlib
#
# `ndarray:`
# - Principal Numpy's array class (also know by array);
# - Multidimensional data structure (N-dimensional n>=2 array);
# - Allows vectorized operations (wth Python loops, making the code fastes n more conscise);
# - Homogeneity ( all elements in the array are of the same data type);
# - Efficient way to represent and manipulate numerical data in Python.
#
# **! Important !**
#
# numpy.ndarray ≠ array.array

# %% [markdown]
# <h1 style="text-align: center; font-family: 'Geneva'; color: #f17ea1;">
#   <span style="background-color: #facef9; padding: 2px 10px; border-radius: 6px; display: inline-block;">
#     <u> Numpy Quickstart </u>
#   </span>
# </h1>

# %% [markdown]
# <h3 style="text-align: left; font-family: 'Geneva'; color: #f17ea1;">
#   <span style="background-color: #facef9; padding: 2px 10px; border-radius: 6px; display: inline-block;">
#      The basics
#   </span>
# </h3>
#
# `axes` = NumPy dimensions
# - 1 axis = a list (vector)
# - 2 axes = a table (matrix)
# - 3 axes = a cube of data
#
# ---
#
# *→ example 1*
#
# `[1, 2, 1]`
#
# - 3D point w/ 1 axis
# - 1 dimensional array, vector
# - Lenght of that axis = 3 (has 3 elements inside it)
# - Shape = 3
#
# ---
#
# *→ example 2*
#
# `[ [1., 0., 0.],`
#
# `[0., 1., 2.] ]`
#
# - First axis → axis 0, vertical direction, rows
#     - Lenght = 2 (2 rows inside principal list)
#
# <br>
#
# - Second axis → axis 1, horizontal direction, columns
#     - Lenght = 3 (3 collumns, internal list has 3 numbers)
#
# <br>
#
# - Shape = (2,3) → 2 rows, 3 columns
#
# ---
#
# More important attributes of an ndarray object are:
#
# `ndarray.ndim` = Number of axes (dimensions) of the array.<br>Example: a 2D matrix has <u>ndim = 2</u>; a vector has <u>ndim = 1</u>
#
# `ndarray.shape` = The dimensions of the array, a tuple (ordered and immutable collection of elements, similar to a list, but which cannot be changed after creation) of integers showing the size along each axis. Lenght `shape` tuple = `ndim`<br>Exemple:a matrix w/ 3 rows and 4 columns has <u>shape = (3,4)<u/>
#
# `ndarray.size` = The total number of elements in the array. Its the product off all elements in `shape`.<br>Exemple: shape = (3, 4), then <u>size = 12<u/>
#
# `ndarray.dtype` = The data type of the elements in the array
#
# | dtype | What it stores | Example |
# |-------|----------------|---------|
# | `int32, int64` | Integers numbers | 1, -5, 100 |
# | `float32, float64` | Decimals numbers | 3.14, -2.5, 0.0 |
# | `bool` | Boolean Values | True, False |
# | `complex` | Complex numbers | 1+2j |
# | `string` | Text | "hello", "numpy" |

# %%
#example 3

# %% [markdown]
# <h2 style="text-align: left; font-family: 'Geneva'; color: #facef9;">
#   <span style="background-color: #f17ea1; padding: 2px 10px; border-radius: 6px; display: inline-block;">
#     Referencess
#   </span>
# </h2>
#
#
# 🔗 [NumPy Learn](https://numpy.org/learn)<br>🔗 [w3schools](https://www.w3schools.com/python/numpy/numpy_data_types.asp)
